# %%
# !pip install markovify

# %%
text = """
Artificial Intelligence is transforming industries across the globe.
Machine Learning enables computers to learn patterns from data.
Deep Learning is a powerful branch of artificial intelligence.
Data Science combines mathematics, statistics, and programming.
Python is widely used in artificial intelligence projects.
Google Colab provides a cloud-based environment for coding.
Technology continues to evolve at a rapid pace.
Cloud computing provides scalable resources for applications.
Artificial Intelligence is improving healthcare systems worldwide.
Businesses use AI to automate repetitive tasks efficiently.
Students can learn programming through practical projects.
Neural networks are inspired by the human brain.
Data analysis helps organizations make informed decisions.
Generative AI can create text, images, music, and videos.
Innovation drives the future of science and technology.
Machine learning models improve with additional data.
Cybersecurity protects systems from digital threats.
Software engineers build applications that solve problems.
Artificial Intelligence improves productivity in many industries.
Many organizations rely on AI-powered solutions.
Learning Python is an excellent step toward becoming a developer.
Researchers are exploring advanced machine learning techniques.
Technology has changed the way people communicate.
Big data helps companies understand customer behavior.
Artificial Intelligence supports smart city development.
Automation reduces human effort in repetitive operations.
Digital transformation is reshaping businesses worldwide.
Computer vision allows machines to interpret visual information.
Natural language processing enables communication between humans and computers.
Artificial Intelligence is revolutionizing education and research.
Data-driven decision making is becoming increasingly important.
Machine learning algorithms can identify hidden patterns.
The future belongs to those who embrace technology.
AI-powered systems improve customer experiences.
Programming skills are valuable in today's digital economy.
Cloud services provide flexibility and reliability.
Innovation creates opportunities for growth and development.
Advanced analytics helps businesses gain insights.
Artificial Intelligence continues to expand into new domains.
Modern technology connects people around the world.
"""

# %%
import markovify

model = markovify.Text(text, state_size=1)

# %%
for i in range(10):
    print(model.make_short_sentence(500))
# Out:
# Innovation drives the globe.
# Neural networks are valuable in artificial intelligence projects.
# Many organizations rely on AI-powered systems from digital threats.
# Big data helps organizations make informed decisions.
# Modern technology connects people around the human effort in today's digital economy.
# Data-driven decision making is transforming industries across the way people communicate.
# Researchers are exploring advanced machine learning algorithms can learn programming through practical projects.
# Artificial Intelligence is transforming industries across the way people communicate.
# Machine Learning Python is widely used in today's digital economy.
# Cybersecurity protects systems improve customer behavior.

# %%
import random

sentences = text.strip().split("\n")

for i in range(10):
    print(random.choice(sentences))
# Out:
# Natural language processing enables communication between humans and computers.
# Programming skills are valuable in today's digital economy.
# Deep Learning is a powerful branch of artificial intelligence.
# Programming skills are valuable in today's digital economy.
# Programming skills are valuable in today's digital economy.
# Innovation drives the future of science and technology.
# Students can learn programming through practical projects.
# Data Science combines mathematics, statistics, and programming.
# AI-powered systems improve customer experiences.
# Artificial Intelligence is revolutionizing education and research.
